# %%
import os
import json
import os.path
if os.path.basename(os.getcwd()) == "notebooks":
    os.chdir('..')
from dotenv import load_dotenv

load_dotenv(".env")  # take environment variables from .env.

from steam_trade_bot.containers import Container
from steam_trade_bot.settings import BotSettings
container = Container()
container.config.from_pydantic(BotSettings())
container.wire(modules=[__name__])

# %%
import pandas as pd
import json
import fastparquet as fp
from functools import lru_cache

from steam_trade_bot.domain.services.sell_history_analyzer import steam_date_str_to_datetime
from steam_trade_bot.domain.fee_calculator import compute_fee_from_total

@lru_cache(maxsize=None)
def compute_fee(price, market_fee):
    fee = compute_fee_from_total(price, market_fee)
    return (fee.payload, fee.game, fee.steam)

@lru_cache(maxsize=None)
def parse_date(s):
    return steam_date_str_to_datetime(s)

GAME_DEFAULT_FEE = 0.1

def method_a(x):
    return (parse_date(x[0]), round(x[1], 2), int(x[2]))

def method_b(row):
    return compute_fee(row["price"], row["market_fee"])

uow_ = container.repositories.unit_of_work
append = False
async with uow_() as uow:
    for game in (await uow.game.get_all()):
        print(f"Processing '{game.name}'")
        market_items = await uow.market_item.get_all(app_id=game.app_id)
        items_df = pd.DataFrame(market_items)
        if items_df.empty:
            continue
        items_df = items_df.fillna(value={"market_fee": GAME_DEFAULT_FEE})
        items_df["market_fee"] = items_df["market_fee"].astype(float)
        items_df["market_fee"] = items_df["market_fee"].apply(lambda x: round(x, 2))
        async for batch in uow.sell_history.yield_all(app_id=game.app_id, currency=1, count=1000):
            df = pd.DataFrame(batch)
            df["history"] = df["history"].apply(json.loads)
            df = df.explode("history")
            df = df.dropna(subset=["history"])
            df2 = pd.DataFrame(df.history.apply(method_a).tolist(), columns=["timestamp", "price", "amount"])
            df.index = df2.index
            # df = pd.merge(df.drop(["timestamp", "history"], axis=1), df2, left_index=True, right_index=True)
            df = df.drop(["timestamp", "history"], axis=1).join(df2)
            df["timestamp"] = pd.to_datetime(df["timestamp"])
            df = df.merge(items_df[["market_hash_name", "market_fee"]], on="market_hash_name")
            # if the dataframe is empty, we should skip it
            if df.empty:
                continue
            df["partition"] = df.apply(lambda x: x["timestamp"].strftime("%Y-%m"), axis=1)
            # df[["price_no_fee", "game_fee", "steam_fee"]] = df.apply(lambda row: compute_fee(row["price"], row["market_fee"]), axis=1)
            df3 = pd.DataFrame(df[["price", "market_fee"]].apply(method_b, axis=1).tolist(), columns=["price_no_fee", "game_fee", "steam_fee"])
            df = pd.merge(df, df3, left_index=True, right_index=True)
            fp.write("tmp.parquet", df, append=append, write_index=False, compression="SNAPPY", times='int96')
            append = True
            print(f"Processed {len(batch)} rows of '{game.name}'")
# Out:
# Processing 'Banana Shooter'
# Processed 604 rows of 'Banana Shooter'
# Processing 'Flying Pengy'
# Processed 37 rows of 'Flying Pengy'
# Processing 'Killing Floor 2'
# Processed 1000 rows of 'Killing Floor 2'
# Processed 1000 rows of 'Killing Floor 2'
# Processed 456 rows of 'Killing Floor 2'
# Processing 'Gem Forge'
# Processed 29 rows of 'Gem Forge'
# Processing 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 1000 rows of 'Team Fortress 2'
# Processed 597 rows of 'Team Fortress 2'
# Processing 'Counter-Strike: Global Offensive'
# Processed 1000 rows of 'Counter-Strike: Global Offensive'
# Processed 1000 rows of 'Counter-Strike: Global Offensive'
# Processed 1000 rows of 'Counter-Strike: Global Offensive'
# Processed 1000 rows of 'Counter-Strike: Global Offensive'
# Processed 1000 rows of 'Counter-Strike: Global Offensive'
# Processed 1000 rows of 'Counter-Strike: Global Offensive'
# Processed 1000 rows of 'Counter-Strike: Global Offensive'
# Processed 1000 rows of 'Counter-Strike: Global Offensive'
# Processed 1000 rows of 'Counter-Strike: Global Offensive'
# Processed 1000 rows of 'Counter-Strike: Global Offensive'
# Processed 1000 rows of 'Counter-Strike: Global Offensive'
# Processed 1000 rows of 'Counter-Strike: Global Offensive'
# Processed 1000 rows of 'Counter-Strike: Global Offensive'
# Processed 1000 rows of 'Counter-Strike: Global Offensive'
# Processed 1000 rows of 'Counter-Strike: Global Offensive'
# Processed 1000 rows of 'Counter-Strike: Global Offensive'
# Processed 40 rows of 'Counter-Strike: Global Offensive'
# Processing 'PUBG: BATTLEGROUNDS'
# Processed 352 rows of 'PUBG: BATTLEGROUNDS'
# Processing 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 1000 rows of 'Steam'
# Processed 44 rows of 'Steam'
# Processing 'Screeps: World'
# Processed 722 rows of 'Screeps: World'
# Processing 'Robot Roller-Derby Disco Dodgeball'
# Processed 173 rows of 'Robot Roller-Derby Disco Dodgeball'
# Processing 'Alien Hostage'
# Processed 6 rows of 'Alien Hostage'
# Processing 'Golf It!'
# Processed 257 rows of 'Golf It!'
# Processing 'Crab Game'
# Processed 686 rows of 'Crab Game'
# Processing '!Anyway!'
# Processed 268 rows of '!Anyway!'
# Processing 'Hero Siege'
# Processed 90 rows of 'Hero Siege'
# Processing 'PAYDAY 2'
# Processed 1000 rows of 'PAYDAY 2'
# Processed 1000 rows of 'PAYDAY 2'
# Processed 1000 rows of 'PAYDAY 2'
# Processed 966 rows of 'PAYDAY 2'
# Processing 'Rust'
# Processed 1000 rows of 'Rust'
# Processed 1000 rows of 'Rust'
# Processed 744 rows of 'Rust'
# Processing 'Unturned'
# Processed 1000 rows of 'Unturned'
# Processed 1000 rows of 'Unturned'
# Processed 1000 rows of 'Unturned'
# Processed 1000 rows of 'Unturned'
# Processed 1000 rows of 'Unturned'
# Processed 1000 rows of 'Unturned'
# Processed 1000 rows of 'Unturned'
# Processed 1000 rows of 'Unturned'
# Processed 494 rows of 'Unturned'
# Processing 'BLOCKPOST'
# Processed 149 rows of 'BLOCKPOST'
# Processing 'First Day'
# Processed 109 rows of 'First Day'
# Processing 'Space Engineers'
# Processed 229 rows of 'Space Engineers'
# Processing 'WARMODE'
# Processed 196 rows of 'WARMODE'
# Processing 'Just Survive'
# Processing 'Colormeleons'
# Processed 158 rows of 'Colormeleons'
# Processing 'HALF DEAD 2'
# Processed 82 rows of 'HALF DEAD 2'
# Processing 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 1000 rows of 'Dota 2'
# Processed 498 rows of 'Dota 2'
# Processing 'Euro Truck Simulator 2'
# Processed 93 rows of 'Euro Truck Simulator 2'
# Processing 'Call to Arms'
# Processed 163 rows of 'Call to Arms'
# Processing 'Business Tour - Online Multiplayer Board Game'
# Processed 156 rows of 'Business Tour - Online Multiplayer Board Game'
# Processing 'SteamVR'
# Processed 146 rows of 'SteamVR'
# Processing 'Russian Life Simulator'
# Processed 8 rows of 'Russian Life Simulator'
# Processing 'Subnautica'
# Processed 7 rows of 'Subnautica'
# Processing 'Golf With Your Friends'
# Processed 136 rows of 'Golf With Your Friends'
# Processing 'Don't Starve Together'
# Processed 420 rows of 'Don't Starve Together'
# Processing 'Ball 3D: Soccer Online'
# Processed 113 rows of 'Ball 3D: Soccer Online'
# Processing 'Anime Collector: Evo'
# Processed 62 rows of 'Anime Collector: Evo'
# Processing '#monstercakes'
# Processed 1000 rows of '#monstercakes'
# Processed 728 rows of '#monstercakes'
# Processing 'Ratz Instagib 2.0'
# Processed 76 rows of 'Ratz Instagib 2.0'
# Processing 'Z1 Battle Royale'
# Processed 1 rows of 'Z1 Battle Royale'
# Processing 'Missile Tank'
# Processed 5 rows of 'Missile Tank'
# Processing 'BattleBlock Theater'
# Processed 324 rows of 'BattleBlock Theater'
# Processing 'Armello'
# Processed 114 rows of 'Armello'
# Processing 'Savage Resurrection'
# Processed 48 rows of 'Savage Resurrection'
# Processing 'Artifact Classic'
# Processed 237 rows of 'Artifact Classic'
# Processing 'Nine Parchments'
# Processed 34 rows of 'Nine Parchments'
# Processing 'Rival Rampage'
# Processed 19 rows of 'Rival Rampage'
# Processing 'Miscreated'
# Processed 522 rows of 'Miscreated'
# Processing 'Project Winter'
# Processed 1000 rows of 'Project Winter'
# Processed 373 rows of 'Project Winter'
# Processing 'Shoppe Keep 2'
# Processed 49 rows of 'Shoppe Keep 2'
# Processing 'Comedy Night'
# Processed 1 rows of 'Comedy Night'
# Processing 'World of Warships'
# Processed 2 rows of 'World of Warships'
# Processing 'Villages™'
# Processed 206 rows of 'Villages™'
# Processing 'BATTALION: Legacy'
# Processed 483 rows of 'BATTALION: Legacy'
# Processing '→SUMETRICK←'
# Processed 152 rows of '→SUMETRICK←'
# Processing 'Minimum'
# Processing 'Rogue Agent'
# Processed 115 rows of 'Rogue Agent'
# Processing 'Little Bunny'
# Processed 2 rows of 'Little Bunny'
# Processing 'Intralism'
# Processed 40 rows of 'Intralism'
# Processing 'XERA: Survival'
# Processed 427 rows of 'XERA: Survival'
# Processing 'American Truck Simulator'
# Processed 72 rows of 'American Truck Simulator'
# Processing '100% Orange Juice'
# Processed 275 rows of '100% Orange Juice'
# Processing 'Dinosaur Hunt'
# Processed 6 rows of 'Dinosaur Hunt'
# Processing 'Peace Data'
# Processed 20 rows of 'Peace Data'
# Processing 'HALF DEAD 3'
# Processed 34 rows of 'HALF DEAD 3'
# Processing 'Wolflord - Werewolf Online'
# Processed 240 rows of 'Wolflord - Werewolf Online'
# Processing 'Hired Ops'
# Processed 326 rows of 'Hired Ops'
# Processing 'Intruder'
# Processed 205 rows of 'Intruder'
# Processing 'Playcraft'
# Processed 2 rows of 'Playcraft'
# Processing 'Depth'
# Processed 692 rows of 'Depth'
# Processing 'Danger Zombies'
# Processed 1 rows of 'Danger Zombies'
# Processing 'Primal Carnage: Extinction'
# Processed 1000 rows of 'Primal Carnage: Extinction'
# Processed 576 rows of 'Primal Carnage: Extinction'
# Processing 'Burst Into'
# Processed 4 rows of 'Burst Into'
# Processing 'Cartoon Strike'
# Processed 212 rows of 'Cartoon Strike'
# Processing 'Immune'
# Processed 40 rows of 'Immune'
# Processing 'Andarilho'
# Processed 20 rows of 'Andarilho'
# Processing 'All Time Battle'
# Processed 7 rows of 'All Time Battle'
# Processing 'Supraball'
# Processed 237 rows of 'Supraball'
# Processing 'Redout: Enhanced Edition'
# Processed 189 rows of 'Redout: Enhanced Edition'
# Processing 'Day of Infamy'
# Processed 29 rows of 'Day of Infamy'
# Processing 'Lewd & Nude | Anime Collector'
# Processed 16 rows of 'Lewd & Nude | Anime Collector'
# Processing 'Catch It'
# Processed 6 rows of 'Catch It'
# Processing '武侠乂'
# Processed 225 rows of '武侠乂'
# Processing 'Islands of Nyne: Battle Royale'
# Processed 40 rows of 'Islands of Nyne: Battle Royale'
# Processing 'Heliborne Collection'
# Processed 126 rows of 'Heliborne Collection'
# Processing 'Survival Zombies The Inverted Evolution'
# Processed 5 rows of 'Survival Zombies The Inverted Evolution'
# Processing 'Warframe'
# Processed 10 rows of 'Warframe'
# Processing 'Dinosaur Hunt Puzzle'
# Processed 6 rows of 'Dinosaur Hunt Puzzle'
# Processing 'Exit From'
# Processed 46 rows of 'Exit From'
# Processing 'Shankaram: CODE REBORN'
# Processed 1 rows of 'Shankaram: CODE REBORN'
# Processing 'Prison Life'
# Processed 57 rows of 'Prison Life'
# Processing 'Golf Around!'
# Processed 62 rows of 'Golf Around!'
# Processing 'Running Man 3D'
# Processed 3 rows of 'Running Man 3D'
# Processing 'Empires Apart'
# Processed 100 rows of 'Empires Apart'
# Processing 'NeoGeometry'
# Processed 9 rows of 'NeoGeometry'
# Processing 'Struggle Offensive'
# Processed 14 rows of 'Struggle Offensive'
# Processing 'Blade Symphony'
# Processed 92 rows of 'Blade Symphony'
# Processing 'A Hat in Time'
# Processed 139 rows of 'A Hat in Time'
# Processing 'Professor Watts Memory Match: Cats'
# Processed 5 rows of 'Professor Watts Memory Match: Cats'
# Processing 'P.A.S.'
# Processed 98 rows of 'P.A.S.'
# Processing 'Land of Puzzles: Knights'
# Processed 5 rows of 'Land of Puzzles: Knights'
# Processing 'MEGAJUMP'
# Processed 1 rows of 'MEGAJUMP'
# Processing 'Gremlins, Inc.'
# Processed 97 rows of 'Gremlins, Inc.'
# Processing 'SNOW'
# Processed 270 rows of 'SNOW'
# Processing 'Path of Exile'
# Processed 8 rows of 'Path of Exile'
# Processing 'Sins of a Dark Age'
# Processing 'Ballistic Overkill'
# Processed 836 rows of 'Ballistic Overkill'
# Processing 'KurtzPel'
# Processed 309 rows of 'KurtzPel'
# Processing 'Legend of Himari'
# Processed 21 rows of 'Legend of Himari'
# Processing 'Dinosaur Forest'
# Processed 7 rows of 'Dinosaur Forest'
# Processing 'Redmatch 2'
# Processed 4 rows of 'Redmatch 2'
# Processing 'Perfect Heist 2'
# Processed 33 rows of 'Perfect Heist 2'
# Processing 'Natural Selection 2'
# Processed 26 rows of 'Natural Selection 2'
# Processing 'CounterAttack'
# Processed 34 rows of 'CounterAttack'
# Processing 'Machine Hunt'
# Processed 5 rows of 'Machine Hunt'
# Processing 'Endless Maneuver'
# Processed 9 rows of 'Endless Maneuver'
# Processing 'Move or Die'
# Processed 59 rows of 'Move or Die'
# Processing 'Red Wake Carnage'
# Processed 1 rows of 'Red Wake Carnage'
# Processing 'Retail Royale'
# Processed 64 rows of 'Retail Royale'
# Processing 'Get Stuffed!'
# Processed 19 rows of 'Get Stuffed!'
# Processing 'Baka Adventures'
# Processed 109 rows of 'Baka Adventures'
# Processing 'Rounds of Zombies'
# Processed 4 rows of 'Rounds of Zombies'
# Processing 'Brawl of Ages'
# Processed 100 rows of 'Brawl of Ages'
# Processing 'DeDrive'
# Processed 8 rows of 'DeDrive'
# Processing 'Wizards'
# Processed 14 rows of 'Wizards'
# Processing 'INTERSHELTER'
# Processed 42 rows of 'INTERSHELTER'
# Processing 'Balls!🤬🍆'
# Processed 1 rows of 'Balls!🤬🍆'
# Processing 'Project Lounge'
# Processed 36 rows of 'Project Lounge'
# Processing 'Ecchi Cards'
# Processed 6 rows of 'Ecchi Cards'
# Processing 'Atlantis Royale'
# Processed 8 rows of 'Atlantis Royale'
# Processing ''
# Processed 4 rows of ''
# Processing 'Monkey Split'
# Processed 5 rows of 'Monkey Split'
# Processing 'RoboSquare'
# Processed 85 rows of 'RoboSquare'
# Processing 'Defense Clicker'
# Processed 66 rows of 'Defense Clicker'
# Processing 'LET IT DIE'
# Processed 1 rows of 'LET IT DIE'
# Processing 'Boreal Blade'
# Processed 437 rows of 'Boreal Blade'
# Processing 'Bloody Glimpse'
# Processed 1 rows of 'Bloody Glimpse'
# Processing 'UpGun'
# Processed 173 rows of 'UpGun'
# Processing 'Knights Hunt'
# Processed 1 rows of 'Knights Hunt'
# Processing 'Forgotten Lore'
# Processed 68 rows of 'Forgotten Lore'
# Processing 'Wing Breakers'
# Processed 253 rows of 'Wing Breakers'
# Processing 'Voice of Chernobyl'
# Processed 170 rows of 'Voice of Chernobyl'
# Processing 'Reflex Arena'
# Processed 77 rows of 'Reflex Arena'
# Processing 'Awesome Metal Detecting'
# Processed 1000 rows of 'Awesome Metal Detecting'
# Processed 1000 rows of 'Awesome Metal Detecting'
# Processed 1000 rows of 'Awesome Metal Detecting'
# Processed 1000 rows of 'Awesome Metal Detecting'
# Processed 1000 rows of 'Awesome Metal Detecting'
# Processed 1000 rows of 'Awesome Metal Detecting'
# Processed 42 rows of 'Awesome Metal Detecting'
# Processing 'Blood Feed'
# Processed 4 rows of 'Blood Feed'
# Processing 'Land of Puzzles: Battles'
# Processed 5 rows of 'Land of Puzzles: Battles'
# Processing ''
# Processed 12 rows of ''
# Processing 'Clatter'
# Processed 136 rows of 'Clatter'
# Processing 'SpeedRunners'
# Processed 16 rows of 'SpeedRunners'
# Processing 'Bunny Hop League'
# Processed 24 rows of 'Bunny Hop League'
# Processing 'Stardrift Nomads'
# Processed 12 rows of 'Stardrift Nomads'
# Processing 'Moon Bullet'
# Processed 2 rows of 'Moon Bullet'
# Processing 'Avalom: Ancestral Heroes'
# Processed 7 rows of 'Avalom: Ancestral Heroes'
# Processing '中国象棋'
# Processed 3 rows of '中国象棋'
# Processing 'Wallpaper Engine'
# Processed 1 rows of 'Wallpaper Engine'
# Processing 'Loop Craft'
# Processed 24 rows of 'Loop Craft'
# Processing 'Longvinter'
# Processed 3 rows of 'Longvinter'
# Processing 'Capsa'
# Processed 121 rows of 'Capsa'
# Processing 'Emily is Away'
# Processed 4 rows of 'Emily is Away'
# Processing 'Interstellar Rift'
# Processed 20 rows of 'Interstellar Rift'
# Processing 'Birchian Flight Simulator'
# Processing 'PanChira Concentration'
# Processed 29 rows of 'PanChira Concentration'
# Processing 'Sophisticated Puzzles'
# Processed 37 rows of 'Sophisticated Puzzles'
# Processing 'ARCADE'
# Processed 91 rows of 'ARCADE'
# Processing 'Sense of The Devil'
# Processed 1 rows of 'Sense of The Devil'
# Processing 'ZPlague'
# Processed 1 rows of 'ZPlague'
# Processing 'Zombie Grinder'
# Processed 313 rows of 'Zombie Grinder'
# Processing 'Rollers'
# Processed 6 rows of 'Rollers'
# Processing 'Master Arena'
# Processed 85 rows of 'Master Arena'
# Processing 'HUNGER'
# Processed 15 rows of 'HUNGER'
# Processing 'Snowballer'
# Processed 56 rows of 'Snowballer'
# Processing 'CASE 2: Animatronics Survival'
# Processed 32 rows of 'CASE 2: Animatronics Survival'
# Processing 'Soul at Stake - 1v4'
# Processed 1 rows of 'Soul at Stake - 1v4'
# Processing 'Unearthing Process'
# Processed 10 rows of 'Unearthing Process'
# Processing 'Ecchi Puzzle'
# Processed 1 rows of 'Ecchi Puzzle'
# Processing 'USA 2020'
# Processed 59 rows of 'USA 2020'
# Processing 'The Laundry'
# Processed 2 rows of 'The Laundry'
# Processing 'Stack Up (or dive trying)'
# Processed 31 rows of 'Stack Up (or dive trying)'
# Processing 'Last Warrior'
# Processed 17 rows of 'Last Warrior'
# Processing 'Fruit Ninja VR'
# Processed 2 rows of 'Fruit Ninja VR'
# Processing 'Duck Creator'
# Processed 1 rows of 'Duck Creator'
# Processing 'EQ - Countries'
# Processing 'Subsistence'
# Processed 7 rows of 'Subsistence'
# Processing 'Running Man 3D Part2'
# Processed 2 rows of 'Running Man 3D Part2'
# Processing 'Darts and Friends'
# Processed 4 rows of 'Darts and Friends'
# Processing 'Waifu Collector'
# Processed 160 rows of 'Waifu Collector'
# Processing 'The Ultimate Clicker Master of the Universe'
# Processed 1 rows of 'The Ultimate Clicker Master of the Universe'
# Processing 'Poly Squad'
# Processed 288 rows of 'Poly Squad'
# Processing 'Meatball'
# Processed 1 rows of 'Meatball'
# Processing 'West of Red'
# Processed 1 rows of 'West of Red'
# Processing 'Arcadius'
# Processed 53 rows of 'Arcadius'
# Processing 'Groomer'
# Processed 1 rows of 'Groomer'
# Processing 'Deadhold'
# Processed 1 rows of 'Deadhold'
# Processing 'Drone Wars'
# Processed 10 rows of 'Drone Wars'
# Processing 'Killer Tank'
# Processed 1 rows of 'Killer Tank'
# Processing 'DiggerOnline'
# Processed 5 rows of 'DiggerOnline'
# Processing 'Balance Ball'
# Processed 5 rows of 'Balance Ball'
# Processing 'Puzzle: Fire Sticks'
# Processed 1 rows of 'Puzzle: Fire Sticks'
# Processing 'Slymes'
# Processed 48 rows of 'Slymes'
# Processing 'Holopoint'
# Processed 3 rows of 'Holopoint'
# Processing 'Zup! Arena'
# Processed 80 rows of 'Zup! Arena'
# Processing 'Epic Royal'
# Processed 1 rows of 'Epic Royal'
# Processing 'Burst The Game'
# Processed 4 rows of 'Burst The Game'
# Processing 'Neon Defense 1 : Pink Power'
# Processed 32 rows of 'Neon Defense 1 : Pink Power'
# Processing 'SosSurvival'
# Processed 6 rows of 'SosSurvival'
# Processing 'Dodge It! 2'
# Processed 6 rows of 'Dodge It! 2'
# Processing 'Wolcen: Lords of Mayhem'
# Processed 6 rows of 'Wolcen: Lords of Mayhem'
# Processing 'Golf Galore'
# Processed 14 rows of 'Golf Galore'
# Processing 'MegaRats'
# Processed 10 rows of 'MegaRats'
# Processing 'Fisherman's House'
# Processed 1 rows of 'Fisherman's House'
# Processing 'Evil Inquisitor'
# Processed 1 rows of 'Evil Inquisitor'
# Processing 'OLDTV'
# Processed 2 rows of 'OLDTV'
# Processing 'Half-Life: C.A.G.E.D.'
# Processed 13 rows of 'Half-Life: C.A.G.E.D.'
# Processing 'FLYVALNY 20!8'
# Processed 12 rows of 'FLYVALNY 20!8'
# Processing 'Spider Wars'
# Processed 28 rows of 'Spider Wars'
# Processing 'Marble Combat'
# Processed 3 rows of 'Marble Combat'
# Processing 'Throw It'
# Processed 4 rows of 'Throw It'
# Processing '- Arcane Raise -'
# Processed 23 rows of '- Arcane Raise -'
# Processing 'Catch Me If You Can'
# Processed 5 rows of 'Catch Me If You Can'
# Processing 'BEACHED'
# Processed 4 rows of 'BEACHED'
# Processing 'Olea's Descent'
# Processed 2 rows of 'Olea's Descent'
# Processing 'Lifeblood'
# Processed 37 rows of 'Lifeblood'
# Processing 'Children of Orc'
# Processed 1 rows of 'Children of Orc'
# Processing 'DIRECT shot'
# Processing 'Drunken Wrestlers 2'
# Processed 16 rows of 'Drunken Wrestlers 2'
# Processing 'FreeCell Quest'
# Processed 4 rows of 'FreeCell Quest'
# Processing 'Bloody Walls'
# Processed 1 rows of 'Bloody Walls'
# Processing 'Ember Strike'
# Processed 2 rows of 'Ember Strike'
# Processing 'Intralism: Rebuild'
# Processing 'Raptor Territory'
# Processed 1 rows of 'Raptor Territory'
# Processing 'Escapers'
# Processing 'Meth Master'
# Processing 'WAVESHAPER'
# Processing 'Ultimate Muscle Roller Championship'
# Processed 16 rows of 'Ultimate Muscle Roller Championship'
# Processing 'Fragsurf'
# Processing 'Kronorite'
# Processed 18 rows of 'Kronorite'
# Processing 'Meu Mundo'
# Processing 'n-body VR'
# Processed 1 rows of 'n-body VR'
# Processing 'I was rebuilt'
# Processed 6 rows of 'I was rebuilt'
# Processing 'Fire Dogs'
# Processing 'Ball Game Playtest'
# Processing 'UAL: Universal AIM League'
# Processed 4 rows of 'UAL: Universal AIM League'
# Processing 'Mazing'
# Processed 3 rows of 'Mazing'
# Processing 'Impact Point'
# Processed 3 rows of 'Impact Point'
# Processing 'Spirit Bounce'
# Processed 3 rows of 'Spirit Bounce'
# Processing 'Now you can't see me'
# Processing 'Idle Sand Castle'
# Processing 'Achievement Clicker'
# Processing 'Paintball War'
# Processing 'Galaxy Citizen'
# Processed 1 rows of 'Galaxy Citizen'
# Processing 'Cybrus'
# Processed 2 rows of 'Cybrus'
# Processing 'Spell Cast'
# Processing 'Black_Faith.'
# Processed 10 rows of 'Black_Faith.'
# Processing 'COSH'
# Processing 'Died Of Fear'
# Processed 3 rows of 'Died Of Fear'
# Processing 'Undarkened'
# Processed 5 rows of 'Undarkened'
# Processing 'Desert Strait: Operation Online'
# Processed 3 rows of 'Desert Strait: Operation Online'
# Processing 'Mech Anarchy'
# Processed 2 rows of 'Mech Anarchy'
# Processing 'Be Quiet!'
# Processed 2 rows of 'Be Quiet!'
# Processing 'Multi Idle'
# Processing 'Friendly Warfare'
# Processing '飞机女孩'
# Processing 'ULTRARUSH'
# Processing 'Bomberpet'
# Processing 'No Momentum'
# Processing 'Frog Fighters'
# Processing 'Stallion Squad'
# Processed 2 rows of 'Stallion Squad'
# Processing 'Hope Despair Chaos'
# Processing ''
# Processing 'Bullets Are Fatal!'
# Processing 'Countrified'
# Processed 1 rows of 'Countrified'
# Processing 'Young Archaeologist'
# Processed 1 rows of 'Young Archaeologist'
# Processing 'L.S.S II'
# Processed 2 rows of 'L.S.S II'
# Processing 'NeoBoom'
# Processing 'Just Us'
# Processing 'Realms of Darkness'
# Processing 'Battle Of Worldviews'
# Processing 'Aquarium Simulator'
# Processing 'Zeal'
# Processed 1 rows of 'Zeal'
# Processing 'Away From Earth: Mars 2'
# Processed 2 rows of 'Away From Earth: Mars 2'
# Processing 'AVA: Dog Tag'
# Processed 1 rows of 'AVA: Dog Tag'
# Processing 'Necro Wars'
# Processing 'Black Squad'
# Processed 1 rows of 'Black Squad'
# Processing '!4RC4N01D!'
# Processed 1 rows of '!4RC4N01D!'
# Processing ''
# Processed 2 rows of ''
# Processing 'Shoot Mania VR: Fun Zombies'
# Processing 'Realm Revolutions'
# Processing 'WTF'
# Processing ''

# %%
from pyspark.sql import SparkSession
#.config("spark.memory.fraction", 0.8) \
    #.config("spark.sql.shuffle.partitions" , "800") \
    #.config("spark.memory.offHeap.enabled",'true')\
    #.config("spark.memory.offHeap.size","16g")\
spark = SparkSession.builder \
    .master('local[*]') \
    .appName('myAppName') \
    .config("spark.executor.memory", "10g") \
    .config("spark.driver.memory", "10g")\
    .config("spark.sql.shuffle.partitions" , "100") \
    .config('spark.sql.files.maxPartitionBytes', str(250 * 1024 * 1024))\
    .getOrCreate()

# %%
import pyspark.sql.functions as func
from pyspark.sql.types import DecimalType, Row
from pyspark.sql import Window as W

# %%
df = spark.read.format("parquet").load("tmp.parquet")

# %%
df.printSchema()
# Out:
# root
#  |-- app_id: long (nullable = true)
#  |-- market_hash_name: string (nullable = true)
#  |-- currency: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- price: double (nullable = true)
#  |-- amount: long (nullable = true)
#  |-- market_fee: double (nullable = true)
#  |-- partition: string (nullable = true)
#  |-- price_no_fee: double (nullable = true)
#  |-- game_fee: double (nullable = true)
#  |-- steam_fee: double (nullable = true)

# %%
df.show()
# Out:
# +-------+----------------+--------+-------------------+-----+------+----------+---------+------------+--------+---------+
# | app_id|market_hash_name|currency|          timestamp|price|amount|market_fee|partition|price_no_fee|game_fee|steam_fee|
# +-------+----------------+--------+-------------------+-----+------+----------+---------+------------+--------+---------+
# |1949740|      AL48 Metal|       1|2022-07-01 04:00:00| 0.03|    44|       0.1|  2022-07|        0.01|    0.01|     0.01|
# |1949740|      AL48 Metal|       1|2022-07-02 04:00:00| 0.03|    92|       0.1|  2022-07|        0.01|    0.01|     0.01|
# |1949740|      AL48 Metal|       1|2022-07-03 04:00:00| 0.03|    27|       0.1|  2022-07|        0.01|    0.01|     0.01|
# |1949740|      AL48 Metal|       1|2022-07-04 04:00:00| 0.03|   187|       0.1|  2022-07|        0.01|    0.01|     0.01|
# |1949740|      AL48 Metal|       1|2022-07-05 04:00:00| 0.03|    44|       0.1|  2022-07|        0.01|    0.01|     0.01|
# |1949740|      AL48 Metal|       1|2022-07-06 04:00:00| 0.03|   156|       0.1|  2022-07|        0.01|    0.01|     0.01|
# |1949740|      AL48 Metal|       1|2022-07-07 04:00:00| 0.03|    44|       0.1|  2022-07|        0.01|    0.01|     0.01|
# |1949740|      AL48 Metal|       1|2022-07-08 04:00:00| 0.03|    63|       0.1|  2022-07|        0.01|    0.01|     0.01|
# |1949740|      AL48 Metal|       1|2022-07-09 04:00:00| 0.03|    23|       0.1|  2022-07|        0.01|    0.01|     0.01|
# |1949740|      AL48 Metal|       1|2022-07-10 04:00:00| 0.03|    32|       0.1|  2022-07|        0.01|    0.01|     0.01|
# |1949740|      AL48 Metal|       1|2022-07-11 04:00:00| 0.03|    61|       0.1|  2022-07|        0.01|    0.01|     0.01|
# |1949740|      AL48 Metal|       1|2022-07-12 04:00:00| 0.03|    42|       0.1|  2022-07|        0.01|    0.01|     0.01|
# |1949740|      AL48 Metal|       1|2022-07-13 04:00:00| 0.03|   168|       0.1|  2022-07|        0.01|    0.01|     0.01|
# |1949740|      AL48 Metal|       1|2022-07-14 04:00:00| 0.03|   102|       0.1|  2022-07|        0.01|    0.01|     0.01|
# |1949740|      AL48 Metal|       1|2022-07-15 04:00:00| 0.03|    42|       0.1|  2022-07|        0.01|    0.01|     0.01|
# |1949740|      AL48 Metal|       1|2022-07-16 04:00:00| 0.03|    65|       0.1|  2022-07|        0.01|    0.01|     0.01|
# |1949740|      AL48 Metal|       1|2022-07-17 04:00:00| 0.03|    36|       0.1|  2022-07|        0.01|    0.01|     0.01|
# |1949740|      AL48 Metal|       1|2022-07-18 04:00:00| 0.03|    35|       0.1|  2022-07|        0.01|    0.01|     0.01|
# |1949740|      AL48 Metal|       1|2022-07-19 04:00:00| 0.03|    83|       0.1|  2022-07|        0.01|    0.01|     0.01|
# |1949740|      AL48 Metal|       1|2022-07-20 04:00:00| 0.03|    26|       0.1|  2022-07|        0.01|    0.01|     0.01|
# +-------+----------------+--------+-------------------+-----+------+----------+---------+------------+--------+---------+
# only showing top 20 rows

# %%
df.count()
# Out:
# 215930656

# %%
df.write.partitionBy('partition').parquet('parquetv2')

# %%
spark.stop()

# %%
import pandas as pd
uow_ = container.repositories.unit_of_work
VALVE_GAME_IDS = {440, 570, 730, 753, 250820, 583950}
rows = []
async with uow_() as uow:
    for game in (await uow.game.get_all()):
        rows.append((game.app_id, game.name, game.app_id in VALVE_GAME_IDS))
        
games_df = pd.DataFrame(rows, columns=["app_id", "app_name", "is_valve_publisher"])
games_df.to_parquet('apps.parquet')
